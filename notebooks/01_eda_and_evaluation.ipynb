# %% [markdown]
# # Multimodal RAG — EDA & Evaluation
#
# Run after indexing sample data with `python scripts/migrate_data.py`.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT))

from src.core.retriever import MultimodalRetriever
from src.database.vector_store import VectorStore

store = VectorStore()
print("Indexed documents:", store.count())

retriever = MultimodalRetriever(store)
query = "What topics are covered in the knowledge base?"
hits = retriever.retrieve(query, top_k=5)
for h in hits:
    print(h["score"], h["metadata"].get("filename"), h["content"][:120])
